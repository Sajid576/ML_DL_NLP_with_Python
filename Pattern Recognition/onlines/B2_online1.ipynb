# %%
[[i*j for j in range(1,10)] for i in range(6,8) ]
# Out:
# [[6, 12, 18, 24, 30, 36, 42, 48, 54], [7, 14, 21, 28, 35, 42, 49, 56, 63]]

# %%
laist=[10,1,0,'AUST']
laist.reverse()
print(laist)
laist[:3]
# Out:
# ['AUST', 0, 1, 10]
# ['AUST', 0, 1]

# %%
import collections
a=dict()
a=collections.defaultdict(int)
print(a[0])
# Out:
# 0

# %%
sTemp="Ahsanullah University of Science"

# %%
def add(x):
    return (x+x)
def multiply(x):
    return(x*x)
funcs=[add,multiply]
for i in range(4):
    value=list(map(lambda x:x(i),funcs))
    print(value)
# Out:
# [0, 0]
# [2, 1]
# [4, 4]
# [6, 9]
